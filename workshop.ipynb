# %%
print('hello world')
# Out:
# hello world

# %%
print(range(10))
# Out:
# range(0, 10)

# %%
# ?pd.read_csv
# Out:
# Object `pd.read_csv` not found.

# %% [markdown]
# # https://github.com/weikang9009/pysal_AAG2018

# %% [markdown]
# markdown cells render like they're text

# %%
10 ** 2
# Out:
# 100

# %% [markdown]
# # can have headings, subheadings, lists
#
# - like
# - this
# - list
# - an extra item
#
#
# 1. or
# 2. autonumbered
# 5. ones
#
# > quotes can be led off email-style, by an arrow
#
# and `monospace` works inline as well as broken off into code chunks:
#
# ```python
# def convert_prices(string):
#     return string.strip("$").replace(",", "")
# ```
#
# And, $\\LaTeX$ works, too, both inline (e.g. $x^2 + 5x - 9$) and set off in equation-mode:
#
# $$ \frac{1}{\sigma\sqrt{2\pi}}\exp\left\{\frac{-1}{2\sigma^2}(y-\mu)'(y-\mu)\right\} $$

# %% [markdown]
# # First, we'll read in some pre-cleaned data from insideairbnb.org on New Orleans.

# %%
import pandas as pd
# %matplotlib inline

# %%
# ?pd.read_csv

# %%
listings = pd.read_csv('./data/listings.csv')

# %%
listings.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                         listing_url  \
# 0           0             0  https://www.airbnb.com/rooms/10291
# 1           1             1  https://www.airbnb.com/rooms/19091
# 2           2             2  https://www.airbnb.com/rooms/26834
# 3           3             3  https://www.airbnb.com/rooms/32250
# 4           4             4  https://www.airbnb.com/rooms/53173
#
#                                                 name  \
# 0                      Spacious Cottage in Mid-City!
# 1                     Fully Furnished Cozy Apartment
# 2                   Maison Mandeville in the Marigny
# 3                Maisonette; Steps to St Charles Ave
# 4  MUST READ >  5 STAR REVIEWS   JAZZ FEST !  BYW...
#
#                                              summary  \
# 0                                                NaN
# 1  This cozy space is a wonder of post-Katrina re...
# 2                                                NaN
# 3  The well-located maisonette (little house) fea...
# 4  The Bywater is the new hot and happening neigh...
#
#                                                space  \
# 0  Spacious house located in Mid-City, New Orlean...
# 1  SEE SPECIAL REDUCED SUMMER PRICING!   This apa...
# 2  Charming shotgun in the Marigny section of tow...
# 3  Come visit our historic maisonette convenientl...
# 4  This is a VERY large bedroom - boasting queen ...
#
#                                          description  host_id  \
# 0  Spacious house located in Mid-City, New Orlean...    31004
# 1  This cozy space is a wonder of post-Katrina re...    72880
# 2  Charming shotgun in the Marigny section of tow...   114452
# 3  The well-located maisonette (little house) fea...   138383
# 4  The Bywater is the new hot and happening neigh...    12154
#
#    host_response_time host_response_rate         ...           \
# 0      within an hour               100%         ...
# 1      within an hour               100%         ...
# 2  within a few hours               100%         ...
# 3      within an hour               100%         ...
# 4      within an hour               100%         ...
#
#          room_type accommodates bathrooms bedrooms beds square_feet  \
# 0  Entire home/apt            4       2.0        3  3.0         NaN
# 1  Entire home/apt            3       1.0        1  1.0       750.0
# 2  Entire home/apt            2       1.0        1  1.0         NaN
# 3  Entire home/apt            2       1.0        1  1.0         NaN
# 4     Private room            2       2.0        1  1.0         NaN
#
#   review_scores_rating instant_bookable reviews_per_month  square_feet_missing
# 0                 97.0                f              0.96                 True
# 1                 97.0                t              3.74                False
# 2                 99.0                f              2.10                 True
# 3                 98.0                f              4.49                 True
# 4                 98.0                f              1.36                 True
#
# [5 rows x 33 columns]

# %%
listings.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'listing_url', 'name', 'summary', 'space',
#        'description', 'host_id', 'host_response_time', 'host_response_rate',
#        'host_is_superhost', 'host_has_profile_pic', 'street', 'neighborhood',
#        'city', 'state', 'zipcode', 'market', 'country', 'latitude',
#        'longitude', 'price', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'square_feet', 'review_scores_rating',
#        'instant_bookable', 'reviews_per_month', 'square_feet_missing'],
#       dtype='object')

# %%
listings.price.hist()

# %%
listings.plot('price')

# %%
listings.plot.scatter('accommodates', 'price')

# %%
listings['square_feet_missing'] = listings.square_feet.isnull()

# %%
listings.square_feet.isnull()
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
# 5        True
# 6       False
# 7       False
# 8       False
# 9        True
# 10       True
# 11       True
# 12       True
# 13      False
# 14      False
# 15      False
# 16       True
# 17       True
# 18      False
# 19       True
# 20       True
# 21      False
# 22       True
# 23       True
# 24       True
# 25       True
# 26      False
# 27      False
# 28       True
# 29       True
#         ...
# 5129     True
# 5130     True
# 5131     True
# 5132     True
# 5133     True
# 5134     True
# 5135     True
# 5136     True
# 5137     True
# 5138     True
# 5139     True
# 5140     True
# 5141     True
# 5142     True
# 5143     True
# 5144     True
# 5145     True
# 5146     True
# 5147     True
# 5148     True
# 5149     True
# 5150     True
# 5151     True
# 5152     True
# 5153     True
# 5154     True
# 5155     True
# 5156     True
# 5157     True
# 5158     True
# Name: square_feet, Length: 5159, dtype: bool

# %%
listings.hist('price',by='square_feet_missing', sharex=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f3d8e6921d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d8e6c3a90>],
#       dtype=object)

# %%
listings.query("price < 200").groupby("square_feet_missing").price.hist(density=True,alpha=.5)
#plt.ylim()
#plt.savefig('figure.png', dpi=300)
# Out:
# square_feet_missing
# False    AxesSubplot(0.125,0.125;0.775x0.755)
# True     AxesSubplot(0.125,0.125;0.775x0.755)
# Name: price, dtype: object

# %%
# ?plt.savefig
# Out:
# Object `plt.savefig` not found.

# %%
listings.groupby("neighborhood").price.agg(['count','mean','std'])\
                                .sort_values('count',ascending=False)
# Out:
#                            count        mean         std
# neighborhood
# Central Business District    716  216.635475  148.413945
# Seventh Ward                 339  172.306785  150.993300
# Central City                 324  171.475309  138.958742
# Treme - Lafitte              322  196.906832  173.989698
# Marigny                      303  212.026403  155.346246
# Mid-City                     302  166.629139  146.043939
# Lower Garden District        220  195.181818  158.781041
# St. Claude                   211  127.957346   90.044238
# Bywater                      203  169.098522  125.419771
# Bayou St. John               130  169.384615  118.785742
# St. Roch                     122  160.475410  133.783482
# Fairgrounds                  119  163.865546  122.101161
# Leonidas                     118  159.271186  150.103250
# Audubon                      111  190.972973  152.428669
# Irish Channel                111  172.198198  136.892182
# Uptown                       100  222.290000  178.037806
# West Riverside                98  207.510204  178.513983
# French Quarter                94  217.936170  125.395444
# East Riverside                91  185.439560  149.673883
# Marlyville - Fontainbleau     88  170.522727  154.737670
# Broadmoor                     83  128.951807   80.535843
# Milan                         82  224.060976  186.872396
# Tulane - Gravier              70  167.571429  110.972718
# Gentilly Terrace              68  142.573529   97.942005
# City Park                     57  180.122807  156.111347
# St. Thomas Dev                56  177.964286  143.909184
# East Carrollton               54  168.777778  120.930304
# Algiers Point                 53  139.716981   66.471329
# Garden District               49  236.224490  169.573149
# Fillmore                      43  163.325581  124.205421
# ...                          ...         ...         ...
# Old Aurora                    20  143.650000  104.706243
# Dillard                       18  154.777778  182.782595
# Mcdonogh                      17  105.235294   48.753884
# Lakeview                      16  135.750000   57.528544
# Navarre                       16  207.500000  155.857627
# Tall Timbers - Brechtel       13  137.923077   74.625132
# West End                      12  187.166667  139.394687
# Whitney                       11  122.272727   59.096685
# Hollygrove                    10  203.300000  177.829538
# Plum Orchard                   8   76.875000   38.457537
# Gentilly Woods                 8  158.750000  103.501208
# Lake Catherine                 7  286.428571  116.215113
# Lower Ninth Ward               7  173.142857  141.150544
# Pontchartrain Park             6  239.166667  195.791130
# Read Blvd East                 6  295.000000  324.653662
# Behrman                        6  103.833333   32.975243
# St. Bernard Area               6  131.000000   73.389373
# Florida Area                   5   76.800000   45.427965
# Desire Area                    4  121.000000   92.036225
# Lake Terrace & Oaks            4  126.250000  166.101124
# Dixon                          4  116.250000   56.263517
# Pines Village                  4   79.000000   53.671842
# Gert Town                      4  121.000000   66.337521
# Lakewood                       3  306.666667  140.118997
# U.S. Naval Base                2  164.500000  120.915260
# Lakeshore - Lake Vista         2  337.500000   17.677670
# New Aurora - English Turn      1   50.000000         NaN
# Iberville                      1  190.000000         NaN
# West Lake Forest               1   81.000000         NaN
# Read Blvd West                 1  275.000000         NaN
#
# [67 rows x 3 columns]

# %% [markdown]
# What if we wanted to know how many neighborhoods have more than 50 listings?

# %%
neighborhoods = listings.groupby("neighborhood")
(neighborhoods.price.count() > 50)
# Out:
# neighborhood
# Algiers Point                 True
# Audubon                       True
# Bayou St. John                True
# Behrman                      False
# Black Pearl                  False
# Broadmoor                     True
# Bywater                       True
# Central Business District     True
# Central City                  True
# City Park                     True
# Desire Area                  False
# Dillard                      False
# Dixon                        False
# East Carrollton               True
# East Riverside                True
# Fairgrounds                   True
# Fillmore                     False
# Florida Area                 False
# French Quarter                True
# Freret                       False
# Garden District              False
# Gentilly Terrace              True
# Gentilly Woods               False
# Gert Town                    False
# Hollygrove                   False
# Holy Cross                   False
# Iberville                    False
# Irish Channel                 True
# Lake Catherine               False
# Lake Terrace & Oaks          False
#                              ...
# Marigny                       True
# Marlyville - Fontainbleau     True
# Mcdonogh                     False
# Mid-City                      True
# Milan                         True
# Milneburg                    False
# Navarre                      False
# New Aurora - English Turn    False
# Old Aurora                   False
# Pines Village                False
# Plum Orchard                 False
# Pontchartrain Park           False
# Read Blvd East               False
# Read Blvd West               False
# Seventh Ward                  True
# St.  Anthony                 False
# St. Bernard Area             False
# St. Claude                    True
# St. Roch                      True
# St. Thomas Dev                True
# Tall Timbers - Brechtel      False
# Touro                        False
# Treme - Lafitte               True
# Tulane - Gravier              True
# U.S. Naval Base              False
# Uptown                        True
# West End                     False
# West Lake Forest             False
# West Riverside                True
# Whitney                      False
# Name: price, Length: 67, dtype: bool

# %%
(neighborhoods.price.count() > 50).sum()
# Out:
# 28

# %% [markdown]
# [Joris's course](https://github.com/jorisvandenbossche/DS-python-data-analysis)

# %% [markdown]
# # Working with spatial data

# %%
import geopandas as gpd
import shapely.geometry as shp
import matplotlib.pyplot as plt
#import rasterio as rio
import numpy as np
import contextily as ctx

# %%
listings.price.head()
# Out:
# 0    300.0
# 1    100.0
# 2    115.0
# 3    140.0
# 4    115.0
# Name: price, dtype: float64

# %%
listings.price.apply(np.log).head()
# Out:
# 0    5.703782
# 1    4.605170
# 2    4.744932
# 3    4.941642
# 4    4.744932
# Name: price, dtype: float64

# %%
listings[['longitude', 'latitude']].head()
# Out:
#    longitude   latitude
# 0 -90.109282  29.986663
# 1 -90.118770  29.962566
# 2 -90.055313  29.965568
# 3 -90.084032  29.933655
# 4 -90.039057  29.964832

# %%
listings[['longitude', 'latitude']].apply(shp.Point).head()
# Out:
# longitude    POINT Z (-90.10928208440596 -90.11876977912294 0)
# latitude        POINT Z (29.98666321152104 29.9625656335813 0)
# dtype: object

# %%
gpd.read_file
# Out:
# <function geopandas.io.file.read_file(filename, **kwargs)>

# %%
listings[['longitude', 'latitude']].apply(shp.Point, axis=1).head()
# Out:
# 0    POINT (-90.10928208440596 29.98666321152104)
# 1     POINT (-90.11876977912294 29.9625656335813)
# 2    POINT (-90.05531293053234 29.96556807082061)
# 3     POINT (-90.0840317471018 29.93365480435372)
# 4    POINT (-90.03905718186577 29.96483236389307)
# dtype: object

# %%
listings['geometry'] = listings[['longitude', 'latitude']].apply(shp.Point, axis=1)

# %%
listings = gpd.GeoDataFrame(listings)

# %%
listings.plot()

# %%
listings.total_bounds
# Out:
# array([-90.13960066,  29.89826583, -89.75353898,  30.14003796])

# %%
listings.crs = {'init':'epsg:4326'}

# %%
west, south, east, north = listings.total_bounds

# %%
ctx.howmany(west, south, east, north, zoom=12, ll=True)
# Out:
# Using zoom level 12, this will download 20 tiles
# 20

# %%
image, bounds_webmerc = ctx.bounds2img(*listings.total_bounds, 
                                          zoom=12, ll=True )

# %%
import rasterio as rio
basemap = rio.open('data/new_orleans.tif')
basemap_image = basemap.read()
basemap_image = basemap_image.transpose(1,2,0)

# %%
plt.imshow(basemap_image, extent=basemap.bounds)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image, extent=bounds_webmerc)
listings.to_crs(epsg=3857).plot('price',
                                ax=plt.gca(), alpha=.2,
                                cmap='plasma', s=1)

# %%
listings = listings.query('longitude < -89.99')

# %%
image, bounds_webmerc = ctx.bounds2img(*listings.total_bounds, 
                                          zoom=14, ll=True)

# %%
f,ax = plt.subplots(1,1,figsize=(10,10))
ax.imshow(image, extent=bounds_webmerc)
listings.to_crs(epsg=3857).plot('price',
                                ax=ax, alpha=.5,
                                cmap='plasma', s=7)
plt.savefig('fig.png')

# %%
import sklearn.cluster as clust

# %%
clust.AgglomerativeClustering
clust.Birch
clust.FeatureAgglomeration
# Out:
# sklearn.cluster.hierarchical.FeatureAgglomeration

# %%
dbscanned = clust.DBSCAN().fit(listings[['longitude', 'latitude']].values)

# %%
f,ax = plt.subplots(1,1,figsize=(10,10))
ax.imshow(image, extent=bounds_webmerc)

(listings.to_crs(epsg=3857)
         .assign(labels = dbscanned.labels_)
         .plot('labels', ax=ax))

# %% [markdown]
# Hmm... I wonder why. Let's look at the dbscan configuration and see why:

# %%
clust.DBSCAN?

# %% [markdown]
# Ah! epsilon must increase, since our data is too close together to let an epsilon of .5 (which would translate to a distance in .5 decimal degrees, which is around 30 miles at this latitude!
#
# So, let's reduce that epsilon down to something more reasonable (e.g. $.0025$).

# %%
dbscanned = (clust.DBSCAN(eps=.0025)
                 .fit(listings[['longitude', 'latitude']].values))

# %%
f,ax = plt.subplots(1,1,figsize=(10,10))
ax.imshow(image, extent=bounds_webmerc)

(listings.to_crs(epsg=3857)
         .assign(labels = dbscanned.labels_)
         .plot('labels', ax=ax))

# %% [markdown]
# Which still are considered "unclassified" by the algorithm?

# %%
unassigned = (listings.assign(labels = dbscanned.labels_)
                      .query('labels == -1')
             )

# %%
f,ax = plt.subplots(1,1,figsize=(10,10))
ax.imshow(image, extent=bounds_webmerc)

(unassigned.to_crs(epsg=3857)
           .plot('labels', ax=ax))

# %% [markdown]
# What if we'd like to mix in price? Well, note that the `DBSCAN` class can take what it calls a "precomputed affinity matrix," which is a matrix describing how similar places are in space. So, if we wanted to, we could compute this ourselves using both spatial information (say, using inverse distance weighting) and price similarity (using another kernel function).

# %%
import pysal as ps

# %%
spatial = ps.weights.Kernel.from_dataframe(listings, fixed=False, 
                                           function='gaussian', k=50)
spatial_matrix = spatial.sparse

# %%
spatial_matrix
# Out:
# <5132x5132 sparse matrix of type '<class 'numpy.float64'>'
# 	with 261732 stored elements in Compressed Sparse Row format>

# %%
plt.matshow(spatial_matrix.toarray())

# %%
import sklearn.metrics as skm

# %%
skm.pairwise.kernel_metrics()
# Out:
# {'additive_chi2': <function sklearn.metrics.pairwise.additive_chi2_kernel(X, Y=None)>,
#  'chi2': <function sklearn.metrics.pairwise.chi2_kernel(X, Y=None, gamma=1.0)>,
#  'linear': <function sklearn.metrics.pairwise.linear_kernel(X, Y=None)>,
#  'polynomial': <function sklearn.metrics.pairwise.polynomial_kernel(X, Y=None, degree=3, gamma=None, coef0=1)>,
#  'poly': <function sklearn.metrics.pairwise.polynomial_kernel(X, Y=None, degree=3, gamma=None, coef0=1)>,
#  'rbf': <function sklearn.metrics.pairwise.rbf_kernel(X, Y=None, gamma=None)>,
#  'laplacian': <function sklearn.metrics.pairwise.laplacian_kernel(X, Y=None, gamma=None)>,
#  'sigmoid': <function sklearn.metrics.pairwise.sigmoid_kernel(X, Y=None, gamma=None, coef0=1)>,
#  'cosine': <function sklearn.metrics.pairwise.cosine_similarity(X, Y=None, dense_output=True)>}

# %%
prices_matrix = skm.pairwise.rbf_kernel(listings[['price']].values, gamma=.001)

# %%
plt.matshow(prices_matrix)

# %%
joint = spatial_matrix.multiply(prices_matrix)

# %%
joint
# Out:
# <5132x5132 sparse matrix of type '<class 'numpy.float64'>'
# 	with 261732 stored elements in COOrdinate format>

# %%
dbscanned = (clust.DBSCAN(eps=.25).fit(joint))

# %%
cores = dbscanned.core_sample_indices_

# %%
coregeoms = listings.iloc[cores]

# %%
f,ax = plt.subplots(1,1,figsize=(10,10))
ax.imshow(image, extent=bounds_webmerc)

(listings.to_crs(epsg=3857)
         .assign(labels=dbscanned.labels_)
           .plot('labels', ax=ax, cmap='Dark2'))
coregeoms.to_crs(epsg=3857)\
         .plot(ax=ax, marker='v')
